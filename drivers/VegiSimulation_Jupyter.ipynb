# %% [markdown]
# ### set up parameters & grid

# %%
import numpy as np
from landlab import RasterModelGrid
from landlab import CLOSED_BOUNDARY, FIXED_VALUE_BOUNDARY
from landlab.components import FlowRouter
from landlab.components import LinearDiffuser
from landlab.components import StreamPowerEroder
from landlab.components import drainage_density
from landlab.components import SedDepEroder
from landlab.io.netcdf import write_netcdf
from landlab.io.netcdf.write import _add_time_variable
#from landlab.components.flow_routing import lake_mapper, DepressionFinderAndRouter
from landlab import imshow_grid
from matplotlib import pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
import time
# %matplotlib inline

# %%
#Grid
ncols = 301
nrows = 301
dx    = 100   #m
vegi_trace_x = 75

#timesteps
out_int  = 100
total_T1 = 10e5       #yrs
dt = 100                #yrs
timeVec = np.arange(0,total_T1,dt) #for plotting purposes
nt = total_T1/dt
no = total_T1/out_int
zp = len(str(int(no)))
#zp = len(str(int(nt)))
#uplift
uplift_rate = 1e-1 #m/yr
uplift_per_step = uplift_rate * dt

#eroder/diffuser
Ksp = 1e-5
msp = 0.6
nsp = 0.8
linear_diffusivity_base = 1e-2 #m^2/s

#critical_area
crit_area = 10e6
#fluvial threshold
thresh_sp = 2.0

#time
elapsed_time = 0

# %%
mg = RasterModelGrid((nrows,ncols),dx)
z = mg.add_ones('node','topographic__elevation',)
#Add some initial roughness to the landscape and some initial water-depth 
initial_roughness = np.random.rand(z.size)/1000
z += initial_roughness

# %% [markdown]
# ### set up boundary - conditions

# %%
for edge in (mg.nodes_at_left_edge,mg.nodes_at_right_edge, mg.nodes_at_top_edge):
    mg.status_at_node[edge] = CLOSED_BOUNDARY
for edge in (mg.nodes_at_bottom_edge):
    mg.status_at_node[edge] = FIXED_VALUE_BOUNDARY

# %% [markdown]
# ### create vegetation field

# %%
vegi_perc = mg.zeros('node',dtype=float)
##THIS CREATES A DEFINED VEGETATION FIELD WITH A FIXED BOUNDARY
#sp_t = mg.ones('node',dtype=float)
#vegi_trace_x = 200
#more_vegi = np.where(mg.x_of_node >= vegi_trace_x)
#less_vegi = np.where(mg.x_of_node < vegi_trace_x)
#vegi_perc[less_vegi] = 0.1
#vegi_perc[more_vegi] = 0.7
##THIS CREATES A RANDOMIZED VEGETATION FIELD
#vegi_perc = np.random.rand(z.size)

##THIS CREATES A SIN-SHAPED VEGETATION TIME-SERIES
#Sin function between 0 and 1
vegi_test_timeseries = (np.sin(0.00015*timeVec)+1)/2 
#Sin function between 0.2 and 0.4
#vegi_test_timeseries = (np.sin(0.00015*timeVec)+ 2) / 9
#Sin function between 0.8 and 1.0
#vegi_test_timeseries = (np.sin(0.00015*timeVec)+ 9) / 10
#imshow_grid(mg,vegi_perc)

# %% [markdown]
# ### Create routine for K-field modulation

# %%
AqDens = 1000.0 #Density of Water [Kg/m^3]
grav   = 9.81   #Gravitational Acceleration [N/Kg]
n_soil = 0.025  #Mannings roughness for soil [-]
n_VRef = 0.2    #Mannings Reference Roughness for Vegi [-]
v_ref  = 0.8    #Reference Vegetation Density
w      = 1.    #Some scaling factor for vegetation [-?]

#Calculations after Istanbulluoglu
nSoil_to_15 = np.power(n_soil, 1.5)
Ford = AqDens * grav * nSoil_to_15
n_v_frac = n_soil + (n_VRef*(vegi_perc/v_ref)) #self.vd = VARIABLE!
n_v_frac_to_w = np.power(n_v_frac, w)
Prefect = np.power(n_v_frac_to_w, 0.9)

Kv = Ksp * Ford/Prefect

# %%
Kfield = mg.zeros('node',dtype = float)
Kfield = Kv
#Kfield[np.where(mg.x_of_node >= vegi_trace_x)] = 5e-3
#imshow_grid(mg,Kfield)

# %% [markdown]
# ### create linear diffusivity field

# %%
lin_diff = mg.zeros('node', dtype = float)
lin_diff = linear_diffusivity_base*np.exp(-vegi_perc)
#lin_diff[np.where(mg.x_of_node >= vegi_trace_x)] = 0.03
#lin_diff[np.where(mg.x_of_node < vegi_trace_x)] = 0.06
#lin_diff += 0.01
#imshow_grid(mg,lin_diff)

# %% [markdown]
# ### Create Field with values of 'threshold_sp', same spatial distribution than vegetation

# %%
threshold_arr = mg.zeros('node',dtype=float)
threshold_arr[np.where(mg.x_of_node <= vegi_trace_x)] += 200
threshold_arr[np.where(mg.x_of_node > vegi_trace_x)] += 200
threshold_field = mg.add_field('node','threshold_sp',threshold_arr,noclobber = False)

# %% [markdown]
# ### initialize the erosional components

# %%
fr = FlowRouter(mg)
ld = LinearDiffuser(mg,linear_diffusivity=lin_diff)
sp = StreamPowerEroder(mg, K_sp = Kfield, m_sp=msp, n_sp=nsp, sp_type = 'set_mn',threshold_sp=thresh_sp)
#df = DepressionFinderAndRouter(mg)

# %% [markdown]
# ### run the main loop

# %%
t0 = time.time()
counter = 0
#DrainageDensity
mean_dd     = []
#Mean, Fluvial, Hillslope Erosion
mean_E      = []
mean_riv_E  = []
mean_hill_E = []
#Mean, Max, Min Slope
mean_slope  = []
max_slope   = []
min_slope   = []
#Mean, Max, Min Elevation
mean_elev   = []
max_elev    = []
min_elev    = []
#Mean_DHDT
mean_dhdt   = []
dhdtArr     = []
#K values River and Diffusivity
mean_K_riv  = []
mean_K_diff = []


#second uplif rate
uplift_per_step = uplift_rate * dt

ncCounter = 0

while elapsed_time < total_T1:
        
    z0 = mg.at_node['topographic__elevation'].copy()
    
    #Actual erosion routines:
    fr.run_one_step(dt=dt)
    ld.run_one_step(dt=dt)
    sp.run_one_step(dt=dt)
    #df.map_depressions()
    
    #Add uplift
    z[mg.core_nodes] += uplift_rate * dt #add uplift
    #z[np.where(mg.x_of_node > 400)] += 2*uplift_rate * dt
    #mg.at_node['topographic__elevation'][mg.boundary_nodes] = 0
    
    #calculate channel_network and drainage density
    channel_mask = mg.at_node['drainage_area'] > crit_area
    dd = drainage_density.DrainageDensity(mg, channel__mask = channel_mask)
    mean_dd.append(dd.calc_drainage_density())
    
    
    #calculate erosion rates by dh/dt diff of matrix4
    dh = mg.at_node['topographic__elevation'] - z0
    dhdt = dh/dt
    dhdtArr.append(dhdt)
    mean_dhdt.append(np.mean(dhdt))
    mean_E.append(np.mean(uplift_rate - dhdt))
    
    #calculates only river erosion rates
    dh_riv = mg.at_node['topographic__elevation'][np.where(mg.at_node['drainage_area'] > crit_area)] - z0[np.where(mg.at_node['drainage_area'] > crit_area)]
    dhdt_riv = dh_riv/dt
    mean_riv_E.append(np.mean(uplift_rate - dhdt_riv))
    
    #calculates hillslope erosion
    dh_hill = mg.at_node['topographic__elevation'][np.where(mg.at_node['drainage_area'] <= crit_area)] - z0[np.where(mg.at_node['drainage_area'] <= crit_area)]
    dhdt_hill = dh_hill/dt
    mean_hill_E.append(np.mean(uplift_rate - dhdt_hill))
    
    #Updates the K-field after every timestep according to the vegetation-field
    vegi_perc = np.random.rand(z.size)/100
    vegi_perc += vegi_test_timeseries[int(elapsed_time/dt)-1]
    vegi_perc.clip(0.,1.)
    n_v_frac = n_soil + (n_VRef*(vegi_perc/v_ref)) #self.vd = VARIABLE!
    n_v_frac_to_w = np.power(n_v_frac, w)
    Prefect = np.power(n_v_frac_to_w, 0.9)
    Kv = Ksp * Ford/Prefect
    Kfield = Kv
    
    #initializes the stream-power-eroder new ? very slow I guess...
    sp = StreamPowerEroder(mg, K_sp = Kfield, m_sp=msp, n_sp=nsp, sp_type = 'set_mn', threshold_sp=thresh_sp)
    
    #LINEAR DIFUSSIVITY
    lin_diff = linear_diffusivity_base*np.exp(-vegi_perc)
    ld = LinearDiffuser(mg,linear_diffusivity=lin_diff)
      
    #save mean_K_diff and mean_K_riv
    mean_K_riv.append(np.mean(Kfield))
    mean_K_diff.append(np.mean(lin_diff))
    
    #save mean, max, min slope
    mean_slope.append(np.mean(mg.at_node['topographic__steepest_slope'][mg.core_nodes]))
    max_slope.append(np.max(mg.at_node['topographic__steepest_slope'][mg.core_nodes]))
    min_slope.append(np.min(mg.at_node['topographic__steepest_slope'][mg.core_nodes]))
    
    #save mean, max, min elev
    mean_elev.append(np.mean(mg.at_node['topographic__elevation'][mg.core_nodes]))
    max_elev.append(np.max(mg.at_node['topographic__elevation'][mg.core_nodes]))
    min_elev.append(np.min(mg.at_node['topographic__elevation'][mg.core_nodes]))
    
    
    #Output every 100 years
    if elapsed_time % out_int == 0:
        print('Elapsed Time:' , elapsed_time,'writing output!')
        plt.figure()
        imshow_grid(mg,'topographic__elevation',grid_units=['km','km'],var_name = 'Elevation',cmap='terrain')
        plt.savefig('./DEM/Testrun_DEM_'+str(int(elapsed_time/out_int)).zfill(zp)+'.png')
        plt.close()
        plt.figure()
        imshow_grid(mg,mg.at_node['drainage_area'] > crit_area)
        plt.savefig('./dd/Testrun_dd_'+str(int(elapsed_time/out_int)).zfill(zp)+'.png')
        plt.close()
        #plt.figure()
        #imshow_grid(mg,fr.drainage_area,cmap='bone')
        #plt.savefig('./ACC/Testrun_ACC_'+str(int(elapsed_time/out_int)).zfill(zp)+'.png')
        #plt.close()
        #write_netcdf('./NC/output{}.nc'.format(str(ncCounter).zfill(zp)), mg, format='NETCDF4')
        
    #update elapsed time
    elapsed_time += dt
tE = time.time()
print()
print('Congratulations. Skript is done took {}s to run'.format(tE - t0))
# Out:
# /Users/mschmid/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/mschmid/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Elapsed Time: 0 writing output!
# /Users/mschmid/landlab/landlab/components/drainage_density/drainage_density.py:204: UserWarning: Existing channel__mask grid field was overwritten.
#   warn("Existing channel__mask grid field was overwritten.")
# Elapsed Time: 100 writing output!
# Elapsed Time: 200 writing output!
# Elapsed Time: 300 writing output!
# Elapsed Time: 400 writing output!
# Elapsed Time: 500 writing output!
# Elapsed Time: 600 writing output!
# Elapsed Time: 700 writing output!
# Elapsed Time: 800 writing output!
# Elapsed Time: 900 writing output!
# Elapsed Time: 1000 writing output!
# Elapsed Time: 1100 writing output!
# Elapsed Time: 1200 writing output!
# Elapsed Time: 1300 writing output!
# Elapsed Time: 1400 writing output!
# Elapsed Time: 1500 writing output!
# Elapsed Time: 1600 writing output!
# Elapsed Time: 1700 writing output!
# Elapsed Time: 1800 writing output!
# Elapsed Time: 1900 writing output!
# Elapsed Time: 2000 writing output!
# Elapsed Time: 2100 writing output!
# Elapsed Time: 2200 writing output!
# Elapsed Time: 2300 writing output!
# Elapsed Time: 2400 writing output!
# Elapsed Time: 2500 writing output!
# Elapsed Time: 2600 writing output!
# Elapsed Time: 2700 writing output!
# Elapsed Time: 2800 writing output!
# Elapsed Time: 2900 writing output!
# Elapsed Time: 3000 writing output!
# Elapsed Time: 3100 writing output!
# Elapsed Time: 3200 writing output!
# Elapsed Time: 3300 writing output!
# Elapsed Time: 3400 writing output!
# Elapsed Time: 3500 writing output!
# Elapsed Time: 3600 writing output!
# Elapsed Time: 3700 writing output!
# Elapsed Time: 3800 writing output!
# Elapsed Time: 3900 writing output!
# Elapsed Time: 4000 writing output!
# Elapsed Time: 4100 writing output!
# Elapsed Time: 4200 writing output!
# Elapsed Time: 4300 writing output!
# Elapsed Time: 4400 writing output!
# Elapsed Time: 4500 writing output!
# Elapsed Time: 4600 writing output!
# Elapsed Time: 4700 writing output!
# Elapsed Time: 4800 writing output!
# Elapsed Time: 4900 writing output!
# Elapsed Time: 5000 writing output!
# Elapsed Time: 5100 writing output!
# Elapsed Time: 5200 writing output!
# Elapsed Time: 5300 writing output!
# Elapsed Time: 5400 writing output!
# Elapsed Time: 5500 writing output!
# Elapsed Time: 5600 writing output!
# Elapsed Time: 5700 writing output!
# Elapsed Time: 5800 writing output!
# Elapsed Time: 5900 writing output!
# Elapsed Time: 6000 writing output!
# Elapsed Time: 6100 writing output!
# Elapsed Time: 6200 writing output!
# Elapsed Time: 6300 writing output!
# Elapsed Time: 6400 writing output!
# Elapsed Time: 6500 writing output!
# Elapsed Time: 6600 writing output!
# Elapsed Time: 6700 writing output!
# Elapsed Time: 6800 writing output!
# Elapsed Time: 6900 writing output!
# Elapsed Time: 7000 writing output!
# Elapsed Time: 7100 writing output!
# Elapsed Time: 7200 writing output!
# Elapsed Time: 7300 writing output!
# Elapsed Time: 7400 writing output!
# Elapsed Time: 7500 writing output!
# Elapsed Time: 7600 writing output!
# Elapsed Time: 7700 writing output!
# Elapsed Time: 7800 writing output!
# Elapsed Time: 7900 writing output!
# Elapsed Time: 8000 writing output!
# Elapsed Time: 8100 writing output!
# Elapsed Time: 8200 writing output!
# Elapsed Time: 8300 writing output!
# Elapsed Time: 8400 writing output!
# Elapsed Time: 8500 writing output!
# Elapsed Time: 8600 writing output!
# Elapsed Time: 8700 writing output!
# Elapsed Time: 8800 writing output!
# Elapsed Time: 8900 writing output!
# Elapsed Time: 9000 writing output!
# Elapsed Time: 9100 writing output!
# Elapsed Time: 9200 writing output!
# Elapsed Time: 9300 writing output!
# Elapsed Time: 9400 writing output!
# Elapsed Time: 9500 writing output!
# Elapsed Time: 9600 writing output!
# Elapsed Time: 9700 writing output!
# Elapsed Time: 9800 writing output!
# Elapsed Time: 9900 writing output!
# Elapsed Time: 10000 writing output!
# Elapsed Time: 10100 writing output!
# Elapsed Time: 10200 writing output!
# Elapsed Time: 10300 writing output!
# Elapsed Time: 10400 writing output!
# Elapsed Time: 10500 writing output!
# Elapsed Time: 10600 writing output!
# Elapsed Time: 10700 writing output!
# Elapsed Time: 10800 writing output!
# Elapsed Time: 10900 writing output!
# Elapsed Time: 11000 writing output!
# Elapsed Time: 11100 writing output!
# Elapsed Time: 11200 writing output!
# Elapsed Time: 11300 writing output!
# Elapsed Time: 11400 writing output!
# Elapsed Time: 11500 writing output!
# Elapsed Time: 11600 writing output!
# Elapsed Time: 11700 writing output!
# Elapsed Time: 11800 writing output!
# Elapsed Time: 11900 writing output!
# Elapsed Time: 12000 writing output!
# Elapsed Time: 12100 writing output!
# Elapsed Time: 12200 writing output!
# Elapsed Time: 12300 writing output!
# Elapsed Time: 12400 writing output!
# Elapsed Time: 12500 writing output!
# Elapsed Time: 12600 writing output!
# Elapsed Time: 12700 writing output!
# Elapsed Time: 12800 writing output!
# Elapsed Time: 12900 writing output!
# Elapsed Time: 13000 writing output!
# Elapsed Time: 13100 writing output!
# Elapsed Time: 13200 writing output!
# Elapsed Time: 13300 writing output!
# Elapsed Time: 13400 writing output!
# Elapsed Time: 13500 writing output!
# Elapsed Time: 13600 writing output!
# Elapsed Time: 13700 writing output!
# Elapsed Time: 13800 writing output!
# Elapsed Time: 13900 writing output!
# Elapsed Time: 14000 writing output!
# Elapsed Time: 14100 writing output!
# Elapsed Time: 14200 writing output!
# Elapsed Time: 14300 writing output!
# Elapsed Time: 14400 writing output!
# Elapsed Time: 14500 writing output!
# Elapsed Time: 14600 writing output!
# Elapsed Time: 14700 writing output!
# Elapsed Time: 14800 writing output!
# Elapsed Time: 14900 writing output!
# Elapsed Time: 15000 writing output!
# Elapsed Time: 15100 writing output!
# Elapsed Time: 15200 writing output!
# Elapsed Time: 15300 writing output!
# Elapsed Time: 15400 writing output!
# Elapsed Time: 15500 writing output!
# Elapsed Time: 15600 writing output!
# Elapsed Time: 15700 writing output!
# Elapsed Time: 15800 writing output!
# Elapsed Time: 15900 writing output!
# Elapsed Time: 16000 writing output!
# Elapsed Time: 16100 writing output!
# Elapsed Time: 16200 writing output!
# Elapsed Time: 16300 writing output!
# Elapsed Time: 16400 writing output!
# Elapsed Time: 16500 writing output!
# Elapsed Time: 16600 writing output!
# Elapsed Time: 16700 writing output!
# Elapsed Time: 16800 writing output!
# Elapsed Time: 16900 writing output!
# Elapsed Time: 17000 writing output!
# Elapsed Time: 17100 writing output!
# Elapsed Time: 17200 writing output!
# Elapsed Time: 17300 writing output!
# Elapsed Time: 17400 writing output!
# Elapsed Time: 17500 writing output!
# Elapsed Time: 17600 writing output!
# Elapsed Time: 17700 writing output!
# Elapsed Time: 17800 writing output!
# Elapsed Time: 17900 writing output!
# Elapsed Time: 18000 writing output!
# Elapsed Time: 18100 writing output!
# Elapsed Time: 18200 writing output!
# Elapsed Time: 18300 writing output!
# Elapsed Time: 18400 writing output!
# Elapsed Time: 18500 writing output!
# Elapsed Time: 18600 writing output!
# Elapsed Time: 18700 writing output!
# Elapsed Time: 18800 writing output!
# Elapsed Time: 18900 writing output!
# Elapsed Time: 19000 writing output!
# Elapsed Time: 19100 writing output!
# Elapsed Time: 19200 writing output!
# Elapsed Time: 19300 writing output!
# Elapsed Time: 19400 writing output!
# Elapsed Time: 19500 writing output!
# Elapsed Time: 19600 writing output!
# Elapsed Time: 19700 writing output!
# Elapsed Time: 19800 writing output!
# Elapsed Time: 19900 writing output!
# Elapsed Time: 20000 writing output!
# Elapsed Time: 20100 writing output!
# Elapsed Time: 20200 writing output!
# Elapsed Time: 20300 writing output!
# Elapsed Time: 20400 writing output!
# Elapsed Time: 20500 writing output!
# Elapsed Time: 20600 writing output!
# Elapsed Time: 20700 writing output!
# Elapsed Time: 20800 writing output!
# Elapsed Time: 20900 writing output!
# Elapsed Time: 21000 writing output!
# Elapsed Time: 21100 writing output!
# Elapsed Time: 21200 writing output!
# Elapsed Time: 21300 writing output!
# Elapsed Time: 21400 writing output!
# Elapsed Time: 21500 writing output!
# Elapsed Time: 21600 writing output!
# Elapsed Time: 21700 writing output!
# Elapsed Time: 21800 writing output!
# Elapsed Time: 21900 writing output!
# Elapsed Time: 22000 writing output!
# Elapsed Time: 22100 writing output!
# Elapsed Time: 22200 writing output!
# Elapsed Time: 22300 writing output!
# Elapsed Time: 22400 writing output!
# Elapsed Time: 22500 writing output!
# Elapsed Time: 22600 writing output!
# Elapsed Time: 22700 writing output!
# Elapsed Time: 22800 writing output!
# Elapsed Time: 22900 writing output!
# Elapsed Time: 23000 writing output!
# Elapsed Time: 23100 writing output!
# Elapsed Time: 23200 writing output!
# Elapsed Time: 23300 writing output!
# Elapsed Time: 23400 writing output!
# Elapsed Time: 23500 writing output!
# Elapsed Time: 23600 writing output!
# Elapsed Time: 23700 writing output!
# Elapsed Time: 23800 writing output!
# Elapsed Time: 23900 writing output!
# Elapsed Time: 24000 writing output!
# Elapsed Time: 24100 writing output!
# Elapsed Time: 24200 writing output!
# Elapsed Time: 24300 writing output!
# Elapsed Time: 24400 writing output!
# Elapsed Time: 24500 writing output!
# Elapsed Time: 24600 writing output!
# Elapsed Time: 24700 writing output!
# Elapsed Time: 24800 writing output!
# Elapsed Time: 24900 writing output!
# Elapsed Time: 25000 writing output!
# Elapsed Time: 25100 writing output!
# Elapsed Time: 25200 writing output!
# Elapsed Time: 25300 writing output!
# Elapsed Time: 25400 writing output!
# Elapsed Time: 25500 writing output!
# Elapsed Time: 25600 writing output!
# Elapsed Time: 25700 writing output!
# Elapsed Time: 25800 writing output!
# Elapsed Time: 25900 writing output!
# Elapsed Time: 26000 writing output!
# Elapsed Time: 26100 writing output!
# Elapsed Time: 26200 writing output!
# Elapsed Time: 26300 writing output!
# Elapsed Time: 26400 writing output!
# Elapsed Time: 26500 writing output!
# Elapsed Time: 26600 writing output!
# Elapsed Time: 26700 writing output!
# Elapsed Time: 26800 writing output!
# Elapsed Time: 26900 writing output!
# Elapsed Time: 27000 writing output!
# Elapsed Time: 27100 writing output!
# Elapsed Time: 27200 writing output!
# Elapsed Time: 27300 writing output!
# Elapsed Time: 27400 writing output!
# Elapsed Time: 27500 writing output!
# Elapsed Time: 27600 writing output!
# Elapsed Time: 27700 writing output!
# Elapsed Time: 27800 writing output!
# Elapsed Time: 27900 writing output!
# Elapsed Time: 28000 writing output!
# Elapsed Time: 28100 writing output!
# Elapsed Time: 28200 writing output!
# Elapsed Time: 28300 writing output!
# Elapsed Time: 28400 writing output!
# Elapsed Time: 28500 writing output!
# Elapsed Time: 28600 writing output!
# Elapsed Time: 28700 writing output!
# Elapsed Time: 28800 writing output!
# Elapsed Time: 28900 writing output!
# Elapsed Time: 29000 writing output!
# Elapsed Time: 29100 writing output!
# Elapsed Time: 29200 writing output!
# Elapsed Time: 29300 writing output!
# Elapsed Time: 29400 writing output!
# Elapsed Time: 29500 writing output!
# Elapsed Time: 29600 writing output!
# Elapsed Time: 29700 writing output!
# Elapsed Time: 29800 writing output!
# Elapsed Time: 29900 writing output!
# Elapsed Time: 30000 writing output!
# Elapsed Time: 30100 writing output!
# Elapsed Time: 30200 writing output!
# Elapsed Time: 30300 writing output!
# Elapsed Time: 30400 writing output!
# Elapsed Time: 30500 writing output!
# Elapsed Time: 30600 writing output!
# Elapsed Time: 30700 writing output!
# Elapsed Time: 30800 writing output!
# Elapsed Time: 30900 writing output!
# Elapsed Time: 31000 writing output!
# Elapsed Time: 31100 writing output!
# Elapsed Time: 31200 writing output!
# Elapsed Time: 31300 writing output!
# Elapsed Time: 31400 writing output!
# Elapsed Time: 31500 writing output!
# Elapsed Time: 31600 writing output!
# Elapsed Time: 31700 writing output!
# Elapsed Time: 31800 writing output!
# Elapsed Time: 31900 writing output!
# Elapsed Time: 32000 writing output!
# Elapsed Time: 32100 writing output!
# Elapsed Time: 32200 writing output!
# Elapsed Time: 32300 writing output!
# Elapsed Time: 32400 writing output!
# Elapsed Time: 32500 writing output!
# Elapsed Time: 32600 writing output!
# Elapsed Time: 32700 writing output!
# Elapsed Time: 32800 writing output!
# Elapsed Time: 32900 writing output!
# Elapsed Time: 33000 writing output!
# Elapsed Time: 33100 writing output!
# Elapsed Time: 33200 writing output!
# Elapsed Time: 33300 writing output!
# Elapsed Time: 33400 writing output!
# Elapsed Time: 33500 writing output!
# Elapsed Time: 33600 writing output!
# Elapsed Time: 33700 writing output!
# Elapsed Time: 33800 writing output!
# Elapsed Time: 33900 writing output!
# Elapsed Time: 34000 writing output!
# Elapsed Time: 34100 writing output!
# Elapsed Time: 34200 writing output!
# Elapsed Time: 34300 writing output!
# Elapsed Time: 34400 writing output!
# Elapsed Time: 34500 writing output!
# Elapsed Time: 34600 writing output!
# Elapsed Time: 34700 writing output!
# Elapsed Time: 34800 writing output!
# Elapsed Time: 34900 writing output!
# Elapsed Time: 35000 writing output!
# Elapsed Time: 35100 writing output!
# Elapsed Time: 35200 writing output!
# Elapsed Time: 35300 writing output!
# Elapsed Time: 35400 writing output!
# Elapsed Time: 35500 writing output!
# Elapsed Time: 35600 writing output!
# Elapsed Time: 35700 writing output!
# Elapsed Time: 35800 writing output!
# Elapsed Time: 35900 writing output!
# Elapsed Time: 36000 writing output!
# Elapsed Time: 36100 writing output!
# Elapsed Time: 36200 writing output!
# Elapsed Time: 36300 writing output!
# Elapsed Time: 36400 writing output!
# Elapsed Time: 36500 writing output!
# Elapsed Time: 36600 writing output!
# Elapsed Time: 36700 writing output!
# Elapsed Time: 36800 writing output!
# Elapsed Time: 36900 writing output!
# Elapsed Time: 37000 writing output!
# Elapsed Time: 37100 writing output!
# Elapsed Time: 37200 writing output!
# Elapsed Time: 37300 writing output!
# Elapsed Time: 37400 writing output!
# Elapsed Time: 37500 writing output!
# Elapsed Time: 37600 writing output!
# Elapsed Time: 37700 writing output!
# Elapsed Time: 37800 writing output!
# Elapsed Time: 37900 writing output!
# Elapsed Time: 38000 writing output!
# Elapsed Time: 38100 writing output!
# Elapsed Time: 38200 writing output!
# Elapsed Time: 38300 writing output!
# Elapsed Time: 38400 writing output!
# Elapsed Time: 38500 writing output!
# Elapsed Time: 38600 writing output!
# Elapsed Time: 38700 writing output!
# Elapsed Time: 38800 writing output!
# Elapsed Time: 38900 writing output!
# Elapsed Time: 39000 writing output!
# Elapsed Time: 39100 writing output!
# Elapsed Time: 39200 writing output!
# Elapsed Time: 39300 writing output!
# Elapsed Time: 39400 writing output!
# Elapsed Time: 39500 writing output!
# Elapsed Time: 39600 writing output!
# Elapsed Time: 39700 writing output!
# Elapsed Time: 39800 writing output!
# Elapsed Time: 39900 writing output!
# Elapsed Time: 40000 writing output!
# Elapsed Time: 40100 writing output!
# Elapsed Time: 40200 writing output!
# Elapsed Time: 40300 writing output!
# Elapsed Time: 40400 writing output!
# Elapsed Time: 40500 writing output!
# Elapsed Time: 40600 writing output!
# Elapsed Time: 40700 writing output!
# Elapsed Time: 40800 writing output!
# Elapsed Time: 40900 writing output!
# Elapsed Time: 41000 writing output!
# Elapsed Time: 41100 writing output!
# Elapsed Time: 41200 writing output!
# Elapsed Time: 41300 writing output!
# Elapsed Time: 41400 writing output!
# Elapsed Time: 41500 writing output!
# Elapsed Time: 41600 writing output!
# Elapsed Time: 41700 writing output!
# Elapsed Time: 41800 writing output!
# Elapsed Time: 41900 writing output!
# Elapsed Time: 42000 writing output!
# Elapsed Time: 42100 writing output!
# Elapsed Time: 42200 writing output!
# Elapsed Time: 42300 writing output!
# Elapsed Time: 42400 writing output!
# Elapsed Time: 42500 writing output!
# Elapsed Time: 42600 writing output!
# Elapsed Time: 42700 writing output!
# Elapsed Time: 42800 writing output!
# Elapsed Time: 42900 writing output!
# Elapsed Time: 43000 writing output!
# Elapsed Time: 43100 writing output!
# Elapsed Time: 43200 writing output!
# Elapsed Time: 43300 writing output!
# Elapsed Time: 43400 writing output!
# Elapsed Time: 43500 writing output!
# Elapsed Time: 43600 writing output!
# Elapsed Time: 43700 writing output!
# Elapsed Time: 43800 writing output!
# Elapsed Time: 43900 writing output!
# Elapsed Time: 44000 writing output!
# Elapsed Time: 44100 writing output!
# Elapsed Time: 44200 writing output!
# Elapsed Time: 44300 writing output!
# Elapsed Time: 44400 writing output!
# Elapsed Time: 44500 writing output!
# Elapsed Time: 44600 writing output!
# Elapsed Time: 44700 writing output!
# Elapsed Time: 44800 writing output!
# Elapsed Time: 44900 writing output!
# Elapsed Time: 45000 writing output!
# Elapsed Time: 45100 writing output!
# Elapsed Time: 45200 writing output!
# Elapsed Time: 45300 writing output!
# Elapsed Time: 45400 writing output!
# Elapsed Time: 45500 writing output!
# Elapsed Time: 45600 writing output!
# Elapsed Time: 45700 writing output!
# Elapsed Time: 45800 writing output!
# Elapsed Time: 45900 writing output!
# Elapsed Time: 46000 writing output!
# Elapsed Time: 46100 writing output!
# Elapsed Time: 46200 writing output!
# Elapsed Time: 46300 writing output!
# Elapsed Time: 46400 writing output!
# Elapsed Time: 46500 writing output!
# Elapsed Time: 46600 writing output!
# Elapsed Time: 46700 writing output!
# Elapsed Time: 46800 writing output!
# Elapsed Time: 46900 writing output!
# Elapsed Time: 47000 writing output!
# Elapsed Time: 47100 writing output!
# Elapsed Time: 47200 writing output!
# Elapsed Time: 47300 writing output!
# Elapsed Time: 47400 writing output!
# Elapsed Time: 47500 writing output!
# Elapsed Time: 47600 writing output!
# Elapsed Time: 47700 writing output!
# Elapsed Time: 47800 writing output!
# Elapsed Time: 47900 writing output!
# Elapsed Time: 48000 writing output!
# Elapsed Time: 48100 writing output!
# Elapsed Time: 48200 writing output!
# Elapsed Time: 48300 writing output!
# Elapsed Time: 48400 writing output!
# Elapsed Time: 48500 writing output!
# Elapsed Time: 48600 writing output!
# Elapsed Time: 48700 writing output!
# Elapsed Time: 48800 writing output!
# Elapsed Time: 48900 writing output!
# Elapsed Time: 49000 writing output!
# Elapsed Time: 49100 writing output!
# Elapsed Time: 49200 writing output!
# Elapsed Time: 49300 writing output!
# Elapsed Time: 49400 writing output!
# Elapsed Time: 49500 writing output!
# Elapsed Time: 49600 writing output!
# Elapsed Time: 49700 writing output!
# Elapsed Time: 49800 writing output!
# Elapsed Time: 49900 writing output!
# Elapsed Time: 50000 writing output!
# Elapsed Time: 50100 writing output!
# Elapsed Time: 50200 writing output!
# Elapsed Time: 50300 writing output!
# Elapsed Time: 50400 writing output!
# Elapsed Time: 50500 writing output!
# Elapsed Time: 50600 writing output!
# Elapsed Time: 50700 writing output!
# Elapsed Time: 50800 writing output!
# Elapsed Time: 50900 writing output!
# Elapsed Time: 51000 writing output!
# Elapsed Time: 51100 writing output!
# Elapsed Time: 51200 writing output!
# Elapsed Time: 51300 writing output!
# Elapsed Time: 51400 writing output!
# Elapsed Time: 51500 writing output!
# Elapsed Time: 51600 writing output!
# Elapsed Time: 51700 writing output!
# Elapsed Time: 51800 writing output!
# Elapsed Time: 51900 writing output!
# Elapsed Time: 52000 writing output!
# Elapsed Time: 52100 writing output!
# Elapsed Time: 52200 writing output!
# Elapsed Time: 52300 writing output!
# Elapsed Time: 52400 writing output!
# Elapsed Time: 52500 writing output!
# Elapsed Time: 52600 writing output!
# Elapsed Time: 52700 writing output!
# Elapsed Time: 52800 writing output!
# Elapsed Time: 52900 writing output!
# Elapsed Time: 53000 writing output!
# Elapsed Time: 53100 writing output!
# Elapsed Time: 53200 writing output!
# Elapsed Time: 53300 writing output!
# Elapsed Time: 53400 writing output!
# Elapsed Time: 53500 writing output!
# Elapsed Time: 53600 writing output!
# Elapsed Time: 53700 writing output!
# Elapsed Time: 53800 writing output!
# Elapsed Time: 53900 writing output!
# Elapsed Time: 54000 writing output!
# Elapsed Time: 54100 writing output!
# Elapsed Time: 54200 writing output!
# Elapsed Time: 54300 writing output!
# Elapsed Time: 54400 writing output!
# Elapsed Time: 54500 writing output!
# Elapsed Time: 54600 writing output!
# Elapsed Time: 54700 writing output!
# Elapsed Time: 54800 writing output!
# Elapsed Time: 54900 writing output!
# Elapsed Time: 55000 writing output!
# Elapsed Time: 55100 writing output!
# Elapsed Time: 55200 writing output!
# Elapsed Time: 55300 writing output!
# Elapsed Time: 55400 writing output!
# Elapsed Time: 55500 writing output!
# Elapsed Time: 55600 writing output!
# Elapsed Time: 55700 writing output!
# Elapsed Time: 55800 writing output!
# Elapsed Time: 55900 writing output!
# Elapsed Time: 56000 writing output!
# Elapsed Time: 56100 writing output!
# Elapsed Time: 56200 writing output!
# Elapsed Time: 56300 writing output!
# Elapsed Time: 56400 writing output!
# Elapsed Time: 56500 writing output!
# Elapsed Time: 56600 writing output!
# Elapsed Time: 56700 writing output!
# Elapsed Time: 56800 writing output!
# Elapsed Time: 56900 writing output!
# Elapsed Time: 57000 writing output!
# Elapsed Time: 57100 writing output!
# Elapsed Time: 57200 writing output!
# Elapsed Time: 57300 writing output!
# Elapsed Time: 57400 writing output!
# Elapsed Time: 57500 writing output!
# Elapsed Time: 57600 writing output!
# Elapsed Time: 57700 writing output!
# Elapsed Time: 57800 writing output!
# Elapsed Time: 57900 writing output!
# Elapsed Time: 58000 writing output!
# Elapsed Time: 58100 writing output!
# Elapsed Time: 58200 writing output!
# Elapsed Time: 58300 writing output!
# Elapsed Time: 58400 writing output!
# Elapsed Time: 58500 writing output!
# Elapsed Time: 58600 writing output!
# Elapsed Time: 58700 writing output!
# Elapsed Time: 58800 writing output!
# Elapsed Time: 58900 writing output!
# Elapsed Time: 59000 writing output!
# Elapsed Time: 59100 writing output!
# Elapsed Time: 59200 writing output!
# Elapsed Time: 59300 writing output!
# Elapsed Time: 59400 writing output!
# Elapsed Time: 59500 writing output!
# Elapsed Time: 59600 writing output!
# Elapsed Time: 59700 writing output!
# Elapsed Time: 59800 writing output!
# Elapsed Time: 59900 writing output!
# Elapsed Time: 60000 writing output!
# Elapsed Time: 60100 writing output!
# Elapsed Time: 60200 writing output!
# Elapsed Time: 60300 writing output!
# Elapsed Time: 60400 writing output!
# Elapsed Time: 60500 writing output!
# Elapsed Time: 60600 writing output!
# Elapsed Time: 60700 writing output!
# Elapsed Time: 60800 writing output!
# Elapsed Time: 60900 writing output!
# Elapsed Time: 61000 writing output!
# Elapsed Time: 61100 writing output!
# Elapsed Time: 61200 writing output!
# Elapsed Time: 61300 writing output!
# Elapsed Time: 61400 writing output!
# Elapsed Time: 61500 writing output!
# Elapsed Time: 61600 writing output!
# Elapsed Time: 61700 writing output!
# Elapsed Time: 61800 writing output!
# Elapsed Time: 61900 writing output!
# Elapsed Time: 62000 writing output!
# Elapsed Time: 62100 writing output!
# Elapsed Time: 62200 writing output!
# Elapsed Time: 62300 writing output!
# Elapsed Time: 62400 writing output!
# Elapsed Time: 62500 writing output!
# Elapsed Time: 62600 writing output!
# Elapsed Time: 62700 writing output!
# Elapsed Time: 62800 writing output!
# Elapsed Time: 62900 writing output!
# Elapsed Time: 63000 writing output!
# Elapsed Time: 63100 writing output!
# Elapsed Time: 63200 writing output!
# Elapsed Time: 63300 writing output!
# Elapsed Time: 63400 writing output!
# Elapsed Time: 63500 writing output!
# Elapsed Time: 63600 writing output!
# Elapsed Time: 63700 writing output!
# Elapsed Time: 63800 writing output!
# Elapsed Time: 63900 writing output!
# Elapsed Time: 64000 writing output!
# Elapsed Time: 64100 writing output!
# Elapsed Time: 64200 writing output!
# Elapsed Time: 64300 writing output!
# Elapsed Time: 64400 writing output!
# Elapsed Time: 64500 writing output!
# Elapsed Time: 64600 writing output!
# Elapsed Time: 64700 writing output!
# Elapsed Time: 64800 writing output!
# Elapsed Time: 64900 writing output!
# Elapsed Time: 65000 writing output!
# Elapsed Time: 65100 writing output!
# Elapsed Time: 65200 writing output!
# Elapsed Time: 65300 writing output!
# Elapsed Time: 65400 writing output!
# Elapsed Time: 65500 writing output!
# Elapsed Time: 65600 writing output!
# Elapsed Time: 65700 writing output!
# Elapsed Time: 65800 writing output!
# Elapsed Time: 65900 writing output!
# Elapsed Time: 66000 writing output!
# Elapsed Time: 66100 writing output!
# Elapsed Time: 66200 writing output!
# Elapsed Time: 66300 writing output!
# Elapsed Time: 66400 writing output!
# Elapsed Time: 66500 writing output!
# Elapsed Time: 66600 writing output!
# Elapsed Time: 66700 writing output!
# Elapsed Time: 66800 writing output!
# Elapsed Time: 66900 writing output!
# Elapsed Time: 67000 writing output!
# Elapsed Time: 67100 writing output!
# Elapsed Time: 67200 writing output!
# Elapsed Time: 67300 writing output!
# Elapsed Time: 67400 writing output!
# Elapsed Time: 67500 writing output!
# Elapsed Time: 67600 writing output!
# Elapsed Time: 67700 writing output!
# Elapsed Time: 67800 writing output!
# Elapsed Time: 67900 writing output!
# Elapsed Time: 68000 writing output!
# Elapsed Time: 68100 writing output!
# Elapsed Time: 68200 writing output!
# Elapsed Time: 68300 writing output!
# Elapsed Time: 68400 writing output!
# Elapsed Time: 68500 writing output!
# Elapsed Time: 68600 writing output!
# Elapsed Time: 68700 writing output!
# Elapsed Time: 68800 writing output!
# Elapsed Time: 68900 writing output!
# Elapsed Time: 69000 writing output!
# Elapsed Time: 69100 writing output!
# Elapsed Time: 69200 writing output!
# Elapsed Time: 69300 writing output!
# Elapsed Time: 69400 writing output!
# Elapsed Time: 69500 writing output!
# Elapsed Time: 69600 writing output!
# Elapsed Time: 69700 writing output!
# Elapsed Time: 69800 writing output!
# Elapsed Time: 69900 writing output!
# Elapsed Time: 70000 writing output!
# Elapsed Time: 70100 writing output!
# Elapsed Time: 70200 writing output!
# Elapsed Time: 70300 writing output!
# Elapsed Time: 70400 writing output!
# Elapsed Time: 70500 writing output!
# Elapsed Time: 70600 writing output!
# Elapsed Time: 70700 writing output!
# Elapsed Time: 70800 writing output!
# Elapsed Time: 70900 writing output!
# Elapsed Time: 71000 writing output!
# Elapsed Time: 71100 writing output!
# Elapsed Time: 71200 writing output!
# Elapsed Time: 71300 writing output!
# Elapsed Time: 71400 writing output!
# Elapsed Time: 71500 writing output!
# Elapsed Time: 71600 writing output!
# Elapsed Time: 71700 writing output!
# Elapsed Time: 71800 writing output!
# Elapsed Time: 71900 writing output!
# Elapsed Time: 72000 writing output!
# Elapsed Time: 72100 writing output!
# Elapsed Time: 72200 writing output!
# Elapsed Time: 72300 writing output!
# Elapsed Time: 72400 writing output!
# Elapsed Time: 72500 writing output!
# Elapsed Time: 72600 writing output!
# Elapsed Time: 72700 writing output!
# Elapsed Time: 72800 writing output!
# Elapsed Time: 72900 writing output!
# Elapsed Time: 73000 writing output!
# Elapsed Time: 73100 writing output!
# Elapsed Time: 73200 writing output!
# Elapsed Time: 73300 writing output!
# Elapsed Time: 73400 writing output!
# Elapsed Time: 73500 writing output!
# Elapsed Time: 73600 writing output!
# Elapsed Time: 73700 writing output!
# Elapsed Time: 73800 writing output!
# Elapsed Time: 73900 writing output!
# Elapsed Time: 74000 writing output!
# Elapsed Time: 74100 writing output!
# Elapsed Time: 74200 writing output!
# Elapsed Time: 74300 writing output!
# Elapsed Time: 74400 writing output!
# Elapsed Time: 74500 writing output!
# Elapsed Time: 74600 writing output!
# Elapsed Time: 74700 writing output!
# Elapsed Time: 74800 writing output!
# Elapsed Time: 74900 writing output!
# Elapsed Time: 75000 writing output!
# Elapsed Time: 75100 writing output!
# Elapsed Time: 75200 writing output!
# Elapsed Time: 75300 writing output!
# Elapsed Time: 75400 writing output!
# Elapsed Time: 75500 writing output!
# Elapsed Time: 75600 writing output!
# Elapsed Time: 75700 writing output!
# Elapsed Time: 75800 writing output!
# Elapsed Time: 75900 writing output!
# Elapsed Time: 76000 writing output!
# Elapsed Time: 76100 writing output!
# Elapsed Time: 76200 writing output!
# Elapsed Time: 76300 writing output!
# Elapsed Time: 76400 writing output!
# Elapsed Time: 76500 writing output!
# Elapsed Time: 76600 writing output!
# Elapsed Time: 76700 writing output!
# Elapsed Time: 76800 writing output!
# Elapsed Time: 76900 writing output!
# Elapsed Time: 77000 writing output!
# Elapsed Time: 77100 writing output!
# Elapsed Time: 77200 writing output!
# Elapsed Time: 77300 writing output!
# Elapsed Time: 77400 writing output!
# Elapsed Time: 77500 writing output!
# Elapsed Time: 77600 writing output!
# Elapsed Time: 77700 writing output!
# Elapsed Time: 77800 writing output!
# Elapsed Time: 77900 writing output!
# Elapsed Time: 78000 writing output!
# Elapsed Time: 78100 writing output!
# Elapsed Time: 78200 writing output!
# Elapsed Time: 78300 writing output!
# Elapsed Time: 78400 writing output!
# Elapsed Time: 78500 writing output!
# Elapsed Time: 78600 writing output!
# Elapsed Time: 78700 writing output!
# Elapsed Time: 78800 writing output!
# Elapsed Time: 78900 writing output!
# Elapsed Time: 79000 writing output!
# Elapsed Time: 79100 writing output!
# Elapsed Time: 79200 writing output!
# Elapsed Time: 79300 writing output!
# Elapsed Time: 79400 writing output!
# Elapsed Time: 79500 writing output!
# Elapsed Time: 79600 writing output!
# Elapsed Time: 79700 writing output!
# Elapsed Time: 79800 writing output!
# Elapsed Time: 79900 writing output!
# Elapsed Time: 80000 writing output!
# Elapsed Time: 80100 writing output!
# Elapsed Time: 80200 writing output!
# Elapsed Time: 80300 writing output!
# Elapsed Time: 80400 writing output!
# Elapsed Time: 80500 writing output!
# Elapsed Time: 80600 writing output!
# Elapsed Time: 80700 writing output!
# Elapsed Time: 80800 writing output!
# Elapsed Time: 80900 writing output!
# Elapsed Time: 81000 writing output!
# Elapsed Time: 81100 writing output!
# Elapsed Time: 81200 writing output!
# Elapsed Time: 81300 writing output!
# Elapsed Time: 81400 writing output!
# Elapsed Time: 81500 writing output!
# Elapsed Time: 81600 writing output!
# Elapsed Time: 81700 writing output!
# Elapsed Time: 81800 writing output!
# Elapsed Time: 81900 writing output!
# Elapsed Time: 82000 writing output!
# Elapsed Time: 82100 writing output!
# Elapsed Time: 82200 writing output!
# Elapsed Time: 82300 writing output!
# Elapsed Time: 82400 writing output!
# Elapsed Time: 82500 writing output!
# Elapsed Time: 82600 writing output!
# Elapsed Time: 82700 writing output!
# Elapsed Time: 82800 writing output!
# Elapsed Time: 82900 writing output!
# Elapsed Time: 83000 writing output!
# Elapsed Time: 83100 writing output!
# Elapsed Time: 83200 writing output!
# Elapsed Time: 83300 writing output!
# Elapsed Time: 83400 writing output!
# Elapsed Time: 83500 writing output!
# Elapsed Time: 83600 writing output!
# Elapsed Time: 83700 writing output!
# Elapsed Time: 83800 writing output!
# Elapsed Time: 83900 writing output!
# Elapsed Time: 84000 writing output!
# Elapsed Time: 84100 writing output!
# Elapsed Time: 84200 writing output!
# Elapsed Time: 84300 writing output!
# Elapsed Time: 84400 writing output!
# Elapsed Time: 84500 writing output!
# Elapsed Time: 84600 writing output!
# Elapsed Time: 84700 writing output!
# Elapsed Time: 84800 writing output!
# Elapsed Time: 84900 writing output!
# Elapsed Time: 85000 writing output!
# Elapsed Time: 85100 writing output!
# Elapsed Time: 85200 writing output!
# Elapsed Time: 85300 writing output!
# Elapsed Time: 85400 writing output!
# Elapsed Time: 85500 writing output!
# Elapsed Time: 85600 writing output!
# Elapsed Time: 85700 writing output!
# Elapsed Time: 85800 writing output!
# Elapsed Time: 85900 writing output!
# Elapsed Time: 86000 writing output!
# Elapsed Time: 86100 writing output!
# Elapsed Time: 86200 writing output!
# Elapsed Time: 86300 writing output!
# Elapsed Time: 86400 writing output!
# Elapsed Time: 86500 writing output!
# Elapsed Time: 86600 writing output!
# Elapsed Time: 86700 writing output!
# Elapsed Time: 86800 writing output!
# Elapsed Time: 86900 writing output!
# Elapsed Time: 87000 writing output!
# Elapsed Time: 87100 writing output!
# Elapsed Time: 87200 writing output!
# Elapsed Time: 87300 writing output!
# Elapsed Time: 87400 writing output!
# Elapsed Time: 87500 writing output!
# Elapsed Time: 87600 writing output!
# Elapsed Time: 87700 writing output!
# Elapsed Time: 87800 writing output!
# Elapsed Time: 87900 writing output!
# Elapsed Time: 88000 writing output!
# Elapsed Time: 88100 writing output!
# Elapsed Time: 88200 writing output!
# Elapsed Time: 88300 writing output!
# Elapsed Time: 88400 writing output!
# Elapsed Time: 88500 writing output!
# Elapsed Time: 88600 writing output!
# Elapsed Time: 88700 writing output!
# Elapsed Time: 88800 writing output!
# Elapsed Time: 88900 writing output!
# Elapsed Time: 89000 writing output!
# Elapsed Time: 89100 writing output!
# Elapsed Time: 89200 writing output!
# Elapsed Time: 89300 writing output!
# Elapsed Time: 89400 writing output!
# Elapsed Time: 89500 writing output!
# Elapsed Time: 89600 writing output!
# Elapsed Time: 89700 writing output!
# Elapsed Time: 89800 writing output!
# Elapsed Time: 89900 writing output!
# Elapsed Time: 90000 writing output!
# Elapsed Time: 90100 writing output!
# Elapsed Time: 90200 writing output!
# Elapsed Time: 90300 writing output!
# Elapsed Time: 90400 writing output!
# Elapsed Time: 90500 writing output!
# Elapsed Time: 90600 writing output!
# Elapsed Time: 90700 writing output!
# Elapsed Time: 90800 writing output!
# Elapsed Time: 90900 writing output!
# Elapsed Time: 91000 writing output!
# Elapsed Time: 91100 writing output!
# Elapsed Time: 91200 writing output!
# Elapsed Time: 91300 writing output!
# Elapsed Time: 91400 writing output!
# Elapsed Time: 91500 writing output!
# Elapsed Time: 91600 writing output!
# Elapsed Time: 91700 writing output!
# Elapsed Time: 91800 writing output!
# Elapsed Time: 91900 writing output!
# Elapsed Time: 92000 writing output!
# Elapsed Time: 92100 writing output!
# Elapsed Time: 92200 writing output!
# Elapsed Time: 92300 writing output!
# Elapsed Time: 92400 writing output!
# Elapsed Time: 92500 writing output!
# Elapsed Time: 92600 writing output!
# Elapsed Time: 92700 writing output!
# Elapsed Time: 92800 writing output!
# Elapsed Time: 92900 writing output!
# Elapsed Time: 93000 writing output!
# Elapsed Time: 93100 writing output!
# Elapsed Time: 93200 writing output!
# Elapsed Time: 93300 writing output!
# Elapsed Time: 93400 writing output!
# Elapsed Time: 93500 writing output!
# Elapsed Time: 93600 writing output!
# Elapsed Time: 93700 writing output!
# Elapsed Time: 93800 writing output!
# Elapsed Time: 93900 writing output!
# Elapsed Time: 94000 writing output!
# Elapsed Time: 94100 writing output!
# Elapsed Time: 94200 writing output!
# Elapsed Time: 94300 writing output!
# Elapsed Time: 94400 writing output!
# Elapsed Time: 94500 writing output!
# Elapsed Time: 94600 writing output!
# Elapsed Time: 94700 writing output!
# Elapsed Time: 94800 writing output!
# Elapsed Time: 94900 writing output!
# Elapsed Time: 95000 writing output!
# Elapsed Time: 95100 writing output!
# Elapsed Time: 95200 writing output!
# Elapsed Time: 95300 writing output!
# Elapsed Time: 95400 writing output!
# Elapsed Time: 95500 writing output!
# Elapsed Time: 95600 writing output!
# Elapsed Time: 95700 writing output!
# Elapsed Time: 95800 writing output!
# Elapsed Time: 95900 writing output!
# Elapsed Time: 96000 writing output!
# Elapsed Time: 96100 writing output!
# Elapsed Time: 96200 writing output!
# Elapsed Time: 96300 writing output!
# Elapsed Time: 96400 writing output!
# Elapsed Time: 96500 writing output!
# Elapsed Time: 96600 writing output!
# Elapsed Time: 96700 writing output!
# Elapsed Time: 96800 writing output!
# Elapsed Time: 96900 writing output!
# Elapsed Time: 97000 writing output!
# Elapsed Time: 97100 writing output!
# Elapsed Time: 97200 writing output!
# Elapsed Time: 97300 writing output!
# Elapsed Time: 97400 writing output!
# Elapsed Time: 97500 writing output!
# Elapsed Time: 97600 writing output!
# Elapsed Time: 97700 writing output!
# Elapsed Time: 97800 writing output!
# Elapsed Time: 97900 writing output!
# Elapsed Time: 98000 writing output!
# Elapsed Time: 98100 writing output!
# Elapsed Time: 98200 writing output!
# Elapsed Time: 98300 writing output!
# Elapsed Time: 98400 writing output!
# Elapsed Time: 98500 writing output!
# Elapsed Time: 98600 writing output!
# Elapsed Time: 98700 writing output!
# Elapsed Time: 98800 writing output!
# Elapsed Time: 98900 writing output!
# Elapsed Time: 99000 writing output!
# Elapsed Time: 99100 writing output!
# Elapsed Time: 99200 writing output!
# Elapsed Time: 99300 writing output!
# Elapsed Time: 99400 writing output!
# Elapsed Time: 99500 writing output!
# Elapsed Time: 99600 writing output!
# Elapsed Time: 99700 writing output!
# Elapsed Time: 99800 writing output!
# Elapsed Time: 99900 writing output!
# Elapsed Time: 100000 writing output!
# Elapsed Time: 100100 writing output!
# Elapsed Time: 100200 writing output!
# Elapsed Time: 100300 writing output!
# Elapsed Time: 100400 writing output!
# Elapsed Time: 100500 writing output!
# Elapsed Time: 100600 writing output!
# Elapsed Time: 100700 writing output!
# Elapsed Time: 100800 writing output!
# Elapsed Time: 100900 writing output!
# Elapsed Time: 101000 writing output!
# Elapsed Time: 101100 writing output!
# Elapsed Time: 101200 writing output!
# Elapsed Time: 101300 writing output!
# Elapsed Time: 101400 writing output!
# Elapsed Time: 101500 writing output!
# Elapsed Time: 101600 writing output!
# Elapsed Time: 101700 writing output!
# Elapsed Time: 101800 writing output!
# Elapsed Time: 101900 writing output!
# Elapsed Time: 102000 writing output!
# Elapsed Time: 102100 writing output!
# Elapsed Time: 102200 writing output!
# Elapsed Time: 102300 writing output!
# Elapsed Time: 102400 writing output!
# Elapsed Time: 102500 writing output!
# Elapsed Time: 102600 writing output!
# Elapsed Time: 102700 writing output!
# Elapsed Time: 102800 writing output!
# Elapsed Time: 102900 writing output!
# Elapsed Time: 103000 writing output!
# Elapsed Time: 103100 writing output!
# Elapsed Time: 103200 writing output!
# Elapsed Time: 103300 writing output!

# %% [markdown]
# ## PLOTS

# %% [markdown]
# ### Hillslope Erosion / River Erosion

# %%
fig, ax1 = plt.subplots(figsize = [11,7])
ax2 = ax1.twinx()
ax1.plot(timeVec, mean_hill_E, 'k', alpha = 0.6, linewidth = 2.5)
ax1.plot(timeVec, mean_riv_E, 'k--', alpha = 0.6, linewidth = 2.5)
#ax1.set_ylim([uplift_rate*0.9,uplift_rate*1.1])
ax1.plot(timeVec, mean_E, 'r', linewidth = 4.7)
ax2.plot(timeVec,100*vegi_test_timeseries,'g', linewidth = 4)
#ax2.set_ylim([0,100])

ax1.set_xlabel('years', fontsize = 22)
ax1.set_ylabel('Erosion rate', color='k', fontsize = 22)
ax2.set_ylabel('Vegetation cover [%]', color='k', fontsize = 22)
ax1.legend(['Hillslope Erosion','Fluvial Erosion', 'Total Erosion'], loc = 3, fontsize = 18)
ax2.legend(['Vegetation Cover'], loc = 4, fontsize = 18)
plt.savefig('./VegiEros_dualy.png',dpi = 720)
plt.show()

# %% [markdown]
# ### Vegetation / Drainage Density

# %%
fig, axarr = plt.subplots(5, sharex = True, figsize = [11,14])
axarr[0].plot(timeVec, vegi_test_timeseries,'g', linewidth = 2.5)
axarr[0].set_title('Mean Surface Vegetation', fontsize = 12)
axarr[0].set_ylabel('Vegetation cover')
axarr[1].plot(timeVec, mean_elev, 'k', linewidth = 2.5)
axarr[1].plot(timeVec, max_elev, 'k--', linewidth = 2, alpha = 0.5)
axarr[1].plot(timeVec, min_elev, 'k--', linewidth = 2, alpha = 0.5)
axarr[1].set_title('Mean Elevation', fontsize = 12)
axarr[1].set_ylabel('Mean Elevation [m]')
#axarr[1].set_ylim([0,80])
axarr[2].plot(timeVec, np.degrees(np.arctan(mean_slope)), 'r', linewidth = 2.5)
axarr[2].plot(timeVec, np.degrees(np.arctan(max_slope)), 'r--', linewidth = 2.0, alpha = 0.5)
axarr[2].plot(timeVec, np.degrees(np.arctan(min_slope)), 'r--', linewidth = 2.0, alpha = 0.5)
#axarr[2].set_ylim([0,10])
axarr[2].set_title('Mean Slope', fontsize = 12)
axarr[2].set_ylabel('Mean Slope [°]')
axarr[3].plot(timeVec,mean_dd, 'b', linewidth = 2.5)
axarr[3].set_title('Mean Drainage Density')
axarr[3].set_ylabel('Drainage Density')
axarr[4].plot(timeVec, mean_hill_E, 'g--', linewidth = 2.0, alpha = 0.5)
axarr[4].plot(timeVec, mean_riv_E, 'b--', linewidth = 2.0, alpha = 0.5)
axarr[4].plot(timeVec, mean_E, 'r--', linewidth = 2.2, alpha = 0.8)
axarr[4].legend(['Hillsl.', 'Rivers','Mean'])
axarr[4].set_title("Erosion rates")
axarr[4].set_ylabel('Erosion rate [m/yr]')
axarr[4].set_xlabel('Model Years', fontsize = 12)
plt.savefig('./Multiplot.png',dpi = 720)
plt.show()
#plt.close()

# %% [markdown]
# ### Normalizing metrics

# %%
mean_E_norm = mean_E/np.max(mean_E)
mean_riv_E_norm = mean_riv_E/np.max(mean_riv_E)
mean_hill_E_norm = mean_hill_E/np.max(mean_hill_E)
mean_elev_norm = mean_elev/np.max(mean_elev)
mean_slope_norm = mean_slope/np.max(mean_slope)
mean_dd_norm = mean_dd/np.max(mean_dd)

# %%
fig, ax = plt.subplots(figsize = [11,7])
ax.plot(timeVec,vegi_test_timeseries, 'g--', linewidth = 5, alpha = 0.6)
#ax.plot(timeVec,mean_E_norm,'r--', linewidth = 5)
#ax.plot(timeVec,mean_elev_norm, 'k', linewidth = 5)
ax.plot(timeVec,mean_slope_norm, 'b', linewidth = 5, alpha = 0.7)
ax.plot(timeVec, mean_dd_norm, 'm', linewidth = 5)
#ax.legend(["Vegetation", "Erosion", "Elevation", "Slope", "Drainage Density"])

# %% [markdown]
# ### Maps

# %%
imshow_grid(mg,'topographic__steepest_slope')

# %%
imshow_grid(mg,'topographic__elevation')

# %%
imshow_grid(mg,'drainage_area')

# %%
imshow_grid(mg,mg.at_node['drainage_area'] > crit_area)
